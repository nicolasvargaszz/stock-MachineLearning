# %%
import plotly.express as px 
import pandas as pd
dataframe_nuevo = pd.read_csv("datos_limpios_pro.csv")
dataframe_viejo = pd.read_csv("datos_limpios_sap.csv")

# %%
dataframe_nuevo.columns
# Out:
# Index(['codigo', 'descrip', 'cod_sector', 'fecha', 'design', 'pantone',
#        'nombre_color', 'cantidad', 'suc', 'temporada_venta'],
#       dtype='object')

# %%
dataframe_viejo = dataframe_viejo.drop(columns=['lote'])
dataframe_viejo.columns
# Out:
# Index(['codigo', 'descrip', 'cod_sector', 'fecha', 'design', 'pantone',
#        'nombre_color', 'cantidad', 'suc', 'temporada_venta'],
#       dtype='object')

# %%
dataframe_nuevo = pd.concat([dataframe_nuevo, dataframe_viejo], ignore_index=True)

# %%
dataframe_nuevo.shape
# Out:
# (1844711, 10)

# %%
dataframe_nuevo['fecha'] = pd.to_datetime(dataframe_nuevo['fecha'])

# Extraer el mes y el año de la columna 'fecha'
dataframe_nuevo['mes'] = dataframe_nuevo['fecha'].dt.to_period("M") #MES

# Agrupar por mes, descrip y otras columnas, y sumar las ventas
df_agrupado = dataframe_nuevo.groupby(['mes', 'descrip', 'suc', 'nombre_color', 'design']).agg({'cantidad': 'sum'}).reset_index()

# Renombrar la columna 'cantidad' a 'venta'
df_agrupado = df_agrupado.rename(columns={'cantidad': 'venta'})

# Mostrar el nuevo DataFrame
df_agrupado
# Out:
#             mes                            descrip  suc          nombre_color
# 0       2017-04                            ACETATO    1      BLANCO BRILLANTE  \
# 1       2017-04                            ACETATO    5  LILA ORQUIDEA OSCURO
# 2       2017-04                         ALEMANISCO    1          AZUL OLIMPIA
# 3       2017-04  ALFOMBRA ANTIDESLIZANTE ESTAMPADO    5      BLANCO BRILLANTE
# 4       2017-04       ALFOMBRA ANTIDESLIZANTE LISO    5           AZUL NIEBLA
# ...         ...                                ...  ...                   ...
# 790571  2023-08                  VIYELAS ESTAMPADA    6          SALMON CREMA
# 790572  2023-08                  VIYELAS ESTAMPADA   10      AMARILLO MINERAL
# 790573  2023-08                  VIYELAS ESTAMPADA   10         AZUL MEDIEVAL
# 790574  2023-08                  VIYELAS ESTAMPADA   24      AMARILLO MINERAL
# 790575  2023-08                  VIYELAS ESTAMPADA   30      AMARILLO SPECTRA
#
#              design  venta
# 0       No definido    0.3
# 1       No definido    1.5
# 2       No definido    1.4
# 3       No definido    0.4
# 4       No definido    2.0
# ...             ...    ...
# 790571       TARTAN    3.0
# 790572       FLORAL    1.0
# 790573       TARTAN    1.5
# 790574       FLORAL    0.5
# 790575       TARTAN    0.5
#
# [790576 rows x 6 columns]

# %%
dataframe_nuevo['fecha'] = pd.to_datetime(dataframe_nuevo['fecha'])

# Crear una nueva columna 'mes' con el formato 'YYYY-MM'
dataframe_nuevo['mes'] = dataframe_nuevo['fecha'].dt.strftime('%Y-%m')

# Agrupar por mes, descrip, sumar las ventas y redondear el resultado
df_agrupado = dataframe_nuevo.groupby(['mes', 'descrip'])['cantidad'].sum().reset_index()
df_agrupado['venta'] = df_agrupado['cantidad'].round().astype(int)

# Seleccionar las columnas requeridas en el nuevo DataFrame
df_resultado = df_agrupado[['mes', 'descrip', 'venta']]

# Imprimir el nuevo DataFrame
print(df_resultado)
# Out:
#            mes                            descrip  venta
# 0      2017-04                            ACETATO      2
# 1      2017-04                         ALEMANISCO      1
# 2      2017-04  ALFOMBRA ANTIDESLIZANTE ESTAMPADO      0
# 3      2017-04       ALFOMBRA ANTIDESLIZANTE LISO      2
# 4      2017-04                          ANTISOLAR      2
# ...        ...                                ...    ...
# 35348  2023-08                    VELBOA JACQUARD      1
# 35349  2023-08                        VELBOA SOFT     20
# 35350  2023-08                    VISCOLYCRA LISO   1220
# 35351  2023-08                 VISCOLYCRA MELANGE      9
# 35352  2023-08                  VIYELAS ESTAMPADA     31
#
# [35353 rows x 3 columns]

# %%
# Imprimir el nuevo DataFrame
df_resultado
# Out:
#            mes                            descrip  venta
# 0      2017-04                            ACETATO      2
# 1      2017-04                         ALEMANISCO      1
# 2      2017-04  ALFOMBRA ANTIDESLIZANTE ESTAMPADO      0
# 3      2017-04       ALFOMBRA ANTIDESLIZANTE LISO      2
# 4      2017-04                          ANTISOLAR      2
# ...        ...                                ...    ...
# 35348  2023-08                    VELBOA JACQUARD      1
# 35349  2023-08                        VELBOA SOFT     20
# 35350  2023-08                    VISCOLYCRA LISO   1220
# 35351  2023-08                 VISCOLYCRA MELANGE      9
# 35352  2023-08                  VIYELAS ESTAMPADA     31
#
# [35353 rows x 3 columns]

# %%
# Filtrar el DataFrame solo para la tela 'DIOLEN LISO'
df_diolen_liso = df_resultado[df_resultado['descrip'] == 'DIOLEN LISO']

# Crear la gráfica con Plotly Express
fig = px.line(df_diolen_liso, x='mes', y='venta', title='Ventas de DIOLEN LISO a lo largo del tiempo',
              labels={'venta': 'Ventas', 'mes': 'Mes'},
              line_shape='linear')

# Mostrar la gráfica
fig.show()

# %% [markdown]
# Como podemos ver dataframe viejo hace que nuestros datos no sean para nada estacionarios debido a la antigua mala gestión de las ventas.

# %%
dataframe_nuevo['fecha'] = pd.to_datetime(dataframe_nuevo['fecha'])

# Crear una nueva columna 'mes' con el formato 'YYYY-MM'
dataframe_nuevo['mes'] = dataframe_nuevo['fecha'].dt.strftime('%Y-%m')

# Agrupar por mes, descrip, sumar las ventas y redondear el resultado
df_resultado_nuevo = dataframe_nuevo.groupby(['mes', 'descrip'])['cantidad'].sum().reset_index()
df_resultado_nuevo['venta'] = df_resultado_nuevo['cantidad'].round().astype(int)

# Seleccionar las columnas requeridas en el nuevo DataFrame
df_resultado_nuevo = df_resultado_nuevo[['mes', 'descrip', 'venta']]

# Imprimir el nuevo DataFrame
df_resultado_nuevo
# Out:
#            mes                   descrip  venta
# 0      2021-02  ACCESORIO CINTA TAPIZADO   1697
# 1      2021-02                   ACETATO  16580
# 2      2021-02                ALEMANISCO      2
# 3      2021-02         ALEMANISCO ELUNEY     16
# 4      2021-02        ALEMANISCO PREMIUN     14
# ...        ...                       ...    ...
# 17664  2023-08           VELBOA JACQUARD      1
# 17665  2023-08               VELBOA SOFT     20
# 17666  2023-08           VISCOLYCRA LISO   1220
# 17667  2023-08        VISCOLYCRA MELANGE      9
# 17668  2023-08         VIYELAS ESTAMPADA     31
#
# [17669 rows x 3 columns]

# %%
top_20_mas_vendidos = df_resultado_nuevo.groupby('descrip')['venta'].sum().sort_values(ascending=False).head(20).index

# Filtrar el DataFrame para obtener solo los datos de los 20 elementos más vendidos
df_top_20 = df_resultado_nuevo[df_resultado_nuevo['descrip'].isin(top_20_mas_vendidos)]

# Crear la gráfica con Plotly Express
fig = px.line(df_top_20, x='mes', y='venta', color='descrip', title='Top 20 elementos más vendidos',
              labels={'venta': 'Ventas', 'mes': 'Mes', 'descrip': 'Producto'},
              line_shape='linear')

# Mostrar la gráfica
fig.show()

# %% [markdown]
# # Empezamos a limpiar nuestros datos de cara a entrenar el modelo ARIMA

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

def remove_non_stationary(df, significance_level=0.05, min_sample_size=10): 
    df_stationary = pd.DataFrame(columns=['mes', 'descrip', 'venta'])
    removed_count = 0
    removal_criterion = []

    for product in df['descrip'].unique():
        df_product = df[df['descrip'] == product]

        # Verificar que el tamaño de la muestra sea suficientemente grande porque sino da error.
        if len(df_product) < min_sample_size:
            removed_count += len(df_product)
            removal_criterion.append(f"Producto '{product}': Tamaño de muestra insuficiente.")
            continue

        # Realizar la prueba de Dickey-Fuller aumentada
        result = adfuller(df_product['venta'])
        p_value = result[1]

        if p_value <= significance_level:
            df_stationary = pd.concat([df_stationary, df_product])
        else:
            removed_count += len(df_product)
            removal_criterion.append(f"Producto '{product}': p-value = {p_value} > {significance_level}")

    print(f"Se eliminaron {removed_count} filas no estacionarias.")
    print("Criterios de eliminación:")
    for criterion in removal_criterion:
        print(criterion)

    return df_stationary

df_stationary = remove_non_stationary(df_resultado_nuevo)

# Ahora podemos usar df_stationary para el análisis de ARIMA
# Out:
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:957: RuntimeWarning:
#
# divide by zero encountered in log
# Se eliminaron 7852 filas no estacionarias.
# Criterios de eliminación:
# Producto 'ACCESORIO CINTA TAPIZADO': p-value = 0.9951953033959051 > 0.05
# Producto 'ALEMANISCO ELUNEY': p-value = 0.2050877362751597 > 0.05
# Producto 'ALFOMBRA ANTIDESLIZANTE ESTAMPADO': p-value = 0.21502066573948686 > 0.05
# Producto 'ALFOMBRA ANTIDESLIZANTE LISO': p-value = 0.9418078928096225 > 0.05
# Producto 'ALFOMBRA TAPIZMEL': p-value = 0.4125729325499046 > 0.05
# Producto 'ALFOMBRA TAPIZMEL FELPA': p-value = 0.6490196752012974 > 0.05
# Producto 'ANTISOLAR 3D': p-value = 0.9763626003414191 > 0.05
# Producto 'ANTISOLAR BASKET': p-value = 0.5905069754173223 > 0.05
# Producto 'ANTISOLAR BELICE': p-value = 0.24422414103313234 > 0.05
# Producto 'ANTISOLAR BRILLOSO': p-value = 0.17092257163325614 > 0.05
# Producto 'ANTISOLAR EMBOSS': p-value = 0.060233182013101814 > 0.05
# Producto 'ANTISOLAR PANA': p-value = 0.7797119466028799 > 0.05
# Producto 'ANTISOLAR PANAMA': p-value = 0.6859231369210367 > 0.05
# Producto 'ANTISOLAR RAYAS': Tamaño de muestra insuficiente.
# Producto 'ARPILLERA COLOR': p-value = 0.5449006445474432 > 0.05
# Producto 'BAMBULA LISO': p-value = 0.20676659664475944 > 0.05
# Producto 'BATISTA ESTAMPADO': p-value = 0.42712636400365284 > 0.05
# Producto 'BATISTA LABRADA': p-value = 0.05708391988918393 > 0.05
# Producto 'BLACKOUT XL': p-value = 0.34105437842170105 > 0.05
# Producto 'BOAL RUSTICO ELUNEY': p-value = 0.865768167459391 > 0.05
# Producto 'BOUCLE SASTRE': p-value = 0.1397381932620681 > 0.05
# Producto 'BROCATO UMA LISO': p-value = 0.1944621530548883 > 0.05
# Producto 'BRODERIE': p-value = 0.5128524488828329 > 0.05
# Producto 'CANVAS COTTON': p-value = 0.6291394585939994 > 0.05
# Producto 'CANVAS VINTAGE': p-value = 0.6067409393583241 > 0.05
# Producto 'CASHMERE BRILLOSO': p-value = 0.3409514489398796 > 0.05
# Producto 'CASHMERE INGLES': p-value = 0.08379416398799916 > 0.05
# Producto 'CASHMERE ITALIANO RAYAS': p-value = 0.5432784241702244 > 0.05
# Producto 'CHENILLE BERLIN': p-value = 0.9168023996412694 > 0.05
# Producto 'CHENILLE ESTAMPADO': p-value = 0.41402555257997575 > 0.05
# Producto 'CHENILLE FLOCKING': Tamaño de muestra insuficiente.
# Producto 'CHENILLE LISBOA': p-value = 1.0 > 0.05
# Producto 'CHENILLE MALTA': p-value = 0.07822011900259951 > 0.05
# Producto 'CHENILLE OPERA': Tamaño de muestra insuficiente.
# Producto 'CHENILLE YAKARTA': p-value = 0.20566839327708475 > 0.05
# Producto 'CORDEROY LISO 21B': p-value = 0.23850846160281003 > 0.05
# Producto 'CREPE OSAKA': p-value = 0.08839842884224253 > 0.05
# Producto 'CREPE REVERSIBLE': p-value = 0.07759690618814438 > 0.05
# Producto 'CREPE SATIN': p-value = 0.8596944338719535 > 0.05
# Producto 'CREPE SEDA': Tamaño de muestra insuficiente.
# Producto 'CREPE TWO TONE': p-value = 0.6225935161442718 > 0.05
# Producto 'CUERINA AFELPADA': p-value = 0.45092361835436834 > 0.05
# Producto 'CUERINA COROTEC': p-value = 0.7664946263938632 > 0.05
# Producto 'CUERINA TEXTURADA': p-value = 0.9905143906134638 > 0.05
# Producto 'DENIM EMBOSS': p-value = 0.6814471830638416 > 0.05
# Producto 'DENIM ESTAMPADO': p-value = 0.06742549533742768 > 0.05
# Producto 'DENIM ESTAMPADO LOLA': p-value = 0.08664806105087497 > 0.05
# Producto 'DENIM OXFORD': p-value = 0.18052288409650552 > 0.05
# Producto 'DENIM SPANDEX': Tamaño de muestra insuficiente.
# Producto 'DRIL QUITO ESTAMPADO': p-value = 0.3864601535401512 > 0.05
# Producto 'DRIL VIENA ESTAMPADO': p-value = 0.07198952415760854 > 0.05
# Producto 'DRY FIT': p-value = 0.13332323881023933 > 0.05
# Producto 'DRY FIT PREMIUM': p-value = 0.08934935242026476 > 0.05
# Producto 'DRY SPEED': Tamaño de muestra insuficiente.
# Producto 'ENCAJE': p-value = 0.2828136608584191 > 0.05
# Producto 'ENTRETELA COTTON': p-value = 0.12371961422509115 > 0.05
# Producto 'ENTRETELA DE ARMADO': p-value = 0.39953343240816586 > 0.05
# Producto 'ENTRETELA DE PUNTO': p-value = 0.3096915181137012 > 0.05
# Producto 'ESPIGA TAPICERIA': p-value = 0.20366063987853839 > 0.05
# Producto 'FIBRANA ESTAMPADA': p-value = 0.59604264736754 > 0.05
# Producto 'FIBRANA ESTAMPADA 32S': p-value = 0.20268869758420555 > 0.05
# Producto 'FIBRANA ESTAMPADA ELUNEY': p-value = 0.3027469002376749 > 0.05
# Producto 'FIBRANA LISO ELUNEY': p-value = 0.10923176270855073 > 0.05
# Producto 'FIBRANA REGULAR ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'GABARDINA ALGODON ELUNEY': p-value = 0.751953451295394 > 0.05
# Producto 'GABARDINA AMERICANA': p-value = 0.1241479062015261 > 0.05
# Producto 'GABARDINA COTTON SURE': p-value = 0.6150858496647302 > 0.05
# Producto 'GABARDINA ELASTIZADA LABRADA': p-value = 0.9736810979664312 > 0.05
# Producto 'GABARDINA ESTAMPADO': p-value = 0.28919268639770923 > 0.05
# Producto 'GABARDINA FOURWAY': p-value = 0.9766069386806226 > 0.05
# Producto 'GABARDINA FOURWAY ELUNEY': p-value = 0.3408006061817771 > 0.05
# Producto 'GABARDINA IGNIFUGA': p-value = 0.09222355507014046 > 0.05
# Producto 'GABARDINA KABIL': p-value = 0.8022931876111881 > 0.05
# Producto 'GABARDINA SATEN ESTAMPADO SP': p-value = 0.3854016157208228 > 0.05
# Producto 'GABARDINA SIWAR': p-value = 0.33778961366067806 > 0.05
# Producto 'GABARDINA SIWAR EST SP': p-value = 0.1550768828481479 > 0.05
# Producto 'GABARDINA SPANDEX CANEX': p-value = 0.7296162644036887 > 0.05
# Producto 'GASA ANKARA': p-value = 0.76707452391088 > 0.05
# Producto 'GASA BERNA': p-value = 0.08018771978563005 > 0.05
# Producto 'GASA BOUCLE': p-value = 0.9402262515232415 > 0.05
# Producto 'GASA DIGITAL PRINT': p-value = 0.45626304808962076 > 0.05
# Producto 'GASA EMBOSS': Tamaño de muestra insuficiente.
# Producto 'GASA ESTAMPADO ELUNEY': p-value = 0.11350573512073903 > 0.05
# Producto 'GASA GEORGETTE': p-value = 0.464965821253836 > 0.05
# Producto 'GASA JACQUARD ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'GASA LASER CUT LISO': Tamaño de muestra insuficiente.
# Producto 'GASA LINEN LOOK': p-value = 0.14905861006022936 > 0.05
# Producto 'GASA PARA PINTAR': p-value = 0.9989096935955453 > 0.05
# Producto 'GASA PLISADO ESTAMPADO': p-value = 0.5038154736640142 > 0.05
# Producto 'GASA PREMIUN PRINT': p-value = 0.624735544920373 > 0.05
# Producto 'GASA SATINADA': p-value = 0.10386361185815474 > 0.05
# Producto 'GASA TORNASOL': p-value = 0.14496245717171774 > 0.05
# Producto 'GOMA ELASTICA 25 MM': Tamaño de muestra insuficiente.
# Producto 'GOMA ELASTICA 7 MM': p-value = 0.36833089678710873 > 0.05
# Producto 'GUIPIURE FENDI': p-value = 0.5288661989732271 > 0.05
# Producto 'GUIPIURE GALLIANO': p-value = 0.34138043739063273 > 0.05
# Producto 'GUIPIURE GALLIANO ESTAMPADO': p-value = 0.5701778235823867 > 0.05
# Producto 'GUIPIURE PROENZA': p-value = 0.22449242375650497 > 0.05
# Producto 'HILOS PANAMA COMPOSSE': Tamaño de muestra insuficiente.
# Producto 'HILOS PANAMA LISO': p-value = 0.0669018169366011 > 0.05
# Producto 'HILOS PANAMA RUSTICO': Tamaño de muestra insuficiente.
# Producto 'HILOS RUSTICO RAYAS': Tamaño de muestra insuficiente.
# Producto 'IMPERMEABLE NYLON': p-value = 0.9862594178165657 > 0.05
# Producto 'INTERLOCK COTTON LISO': p-value = 0.2592334562783424 > 0.05
# Producto 'INTERLOCK RAYAS': p-value = 0.06026313281237883 > 0.05
# Producto 'JACQUARD CAMISERO': p-value = 0.9226083631927033 > 0.05
# Producto 'JERSEY COTTON LISO': p-value = 0.06565367688240727 > 0.05
# Producto 'JERSEY ESTAMPADO': p-value = 0.8940366273762018 > 0.05
# Producto 'JERSEY LOLA': p-value = 0.8206681583727544 > 0.05
# Producto 'JERSEY PIQUE RAYAS': p-value = 0.1802174500639231 > 0.05
# Producto 'JERSEY PREMIUM ESTAMPADO': p-value = 0.25433092120085227 > 0.05
# Producto 'JERSEY SEDA': p-value = 0.3184567545602978 > 0.05
# Producto 'LAME PLISSE': p-value = 0.7660822385494284 > 0.05
# Producto 'LIENCILLO LISO': p-value = 0.9923700580887002 > 0.05
# Producto 'LIENCILLO PREMIUM': p-value = 0.9988552762075522 > 0.05
# Producto 'LIENZO': p-value = 0.07203313545936348 > 0.05
# Producto 'LIENZO TUSSOR': p-value = 0.08791146469463534 > 0.05
# Producto 'LINO CREPE BORDADO': p-value = 0.3014188835697552 > 0.05
# Producto 'LINO EVA': p-value = 0.9146121596966195 > 0.05
# Producto 'LINO MELANGE': p-value = 0.8870065997065906 > 0.05
# Producto 'LINO RAMIE': p-value = 0.06907919907701543 > 0.05
# Producto 'LINO RUSTICO': p-value = 0.9962440824590985 > 0.05
# Producto 'LINO SPANDEX LISO': Tamaño de muestra insuficiente.
# Producto 'LYCRA SEDA': p-value = 0.08620150648557678 > 0.05
# Producto 'LYCRA SEDA ELUNEY': p-value = 0.3458474635180063 > 0.05
# Producto 'LYCRA TEXTURIZADA ESTAMPADA': p-value = 0.2320521575582501 > 0.05
# Producto 'MALLA BONDEADO': p-value = 0.09831342895067352 > 0.05
# Producto 'MALLA LUREX': p-value = 0.09346794050624369 > 0.05
# Producto 'MALLA RIGIDA': p-value = 0.06511215660589191 > 0.05
# Producto 'MALLA SEGUNDA PIEL': p-value = 0.36683296567554136 > 0.05
# Producto 'MANTELERIA LINO RUSTICO': Tamaño de muestra insuficiente.
# Producto 'MANTELERIA RUSTICA': p-value = 0.7471192025205529 > 0.05
# Producto 'MANTELERIA TROPICAL CUADRILLE': p-value = 0.29228816287566217 > 0.05
# Producto 'MANTELERIA TROPICAL JACQUARD': p-value = 0.7516489399928388 > 0.05
# Producto 'MANTILLA LANILLADA': Tamaño de muestra insuficiente.
# Producto 'MATELASSE DOBLE PU': Tamaño de muestra insuficiente.
# Producto 'MATELASSE ESTAMPADO': p-value = 1.0 > 0.05
# Producto 'MATELASSE INFANTIL': p-value = 0.6894923847467576 > 0.05
# Producto 'MICRO STRIPES': Tamaño de muestra insuficiente.
# Producto 'MICROTUL LOLA': p-value = 0.16866877573185374 > 0.05
# Producto 'MODAL PLISE ESTAMPADO': p-value = 0.19761742023207496 > 0.05
# Producto 'MOLETON CATIONIC': p-value = 0.8890810568500901 > 0.05
# Producto 'MOLETON INFANTIL': p-value = 0.16733760428661038 > 0.05
# Producto 'MOLETON MELANGE': p-value = 0.7401243755549252 > 0.05
# Producto 'MOLETON STANDARD': p-value = 0.35744418180556103 > 0.05
# Producto 'MOLETON TERRY COTTON': p-value = 0.1038675916157436 > 0.05
# Producto 'MOLETON TERRY FINO RAYAS': p-value = 0.9890930016450885 > 0.05
# Producto 'ORGANZA BIPRINT': p-value = 0.06134490807002425 > 0.05
# Producto 'ORGANZA CRISTAL': p-value = 0.07640932541241267 > 0.05
# Producto 'ORGANZA CRISTAL BR': p-value = 0.42181871017182904 > 0.05
# Producto 'ORGANZA FROZEN': p-value = 0.6660552306286149 > 0.05
# Producto 'OXFORD PREMIUM': p-value = 0.9900249092831502 > 0.05
# Producto 'PAILLETTE GIBRE': p-value = 0.3284672932576712 > 0.05
# Producto 'PAILLETTE ISABELLA': p-value = 0.7449371444885495 > 0.05
# Producto 'PANA APACHE': p-value = 0.3786538880275725 > 0.05
# Producto 'PANA AUTOMOTOR': Tamaño de muestra insuficiente.
# Producto 'PANA BONDEADO': p-value = 0.3043753049316457 > 0.05
# Producto 'PANA ITALIA EMBOSS': p-value = 0.3696704675182797 > 0.05
# Producto 'PANA LONDON': p-value = 0.11010614540237318 > 0.05
# Producto 'PANA MILENIUM': Tamaño de muestra insuficiente.
# Producto 'PANA MONACO': p-value = 0.9889505547392253 > 0.05
# Producto 'PANAMA SONESTA': p-value = 0.21585159208311938 > 0.05
# Producto 'PANHO LANA LIGERO': p-value = 0.11999007955268115 > 0.05
# Producto 'PANHO TWEED ESCOCES': Tamaño de muestra insuficiente.
# Producto 'PANHOLENCI': p-value = 0.17477890540754648 > 0.05
# Producto 'PATA DE GALLO': p-value = 0.1045451224726825 > 0.05
# Producto 'PERCAL 200 HILOS XL': p-value = 0.9902396745588024 > 0.05
# Producto 'PERCAL 320 HILOS': p-value = 0.6730522198620207 > 0.05
# Producto 'PERCAL 320 HILOS ESTAMPADA': p-value = 0.09505542149226154 > 0.05
# Producto 'PERCAL COTTON': Tamaño de muestra insuficiente.
# Producto 'PERCAL COTTON INFANTIL': p-value = 0.9461480774969179 > 0.05
# Producto 'PERCAL LISO': p-value = 0.09793595651098963 > 0.05
# Producto 'PERCAL TC INFANTIL': p-value = 0.4430722307560619 > 0.05
# Producto 'PIQUE ELUNEY': p-value = 0.9657888969586135 > 0.05
# Producto 'PIQUE PILAR ESTAMPADO': p-value = 0.5879639129374783 > 0.05
# Producto 'PIQUE PILAR LISO': p-value = 0.05750972349785259 > 0.05
# Producto 'PIQUE STRECH': p-value = 0.07498641260383167 > 0.05
# Producto 'PIQUE T/C': p-value = 0.939562875791967 > 0.05
# Producto 'PLUMETI LISO': p-value = 0.07031219249030447 > 0.05
# Producto 'POLAR VELBOA EMBOSS': p-value = 1.0 > 0.05
# Producto 'POLAR VELBOA ESTAMPADO XL': p-value = 0.9974658985984012 > 0.05
# Producto 'POPLIN COTTON ELUNEY': p-value = 0.17290293197780027 > 0.05
# Producto 'POPLIN CUADRO MADRAS': p-value = 0.2202525611013924 > 0.05
# Producto 'POPLIN EGIPTO': p-value = 0.8191200975101384 > 0.05
# Producto 'POPLIN ESTAMPADO LOLA': p-value = 0.09623327964859396 > 0.05
# Producto 'POPLIN PREMIER': p-value = 0.7780344370825236 > 0.05
# Producto 'POPLIN SPANDEX RAYAS': Tamaño de muestra insuficiente.
# Producto 'POPLIN TC RAYAS': p-value = 0.11626502072757111 > 0.05
# Producto 'PUNTO ROMA': p-value = 0.05672115107284936 > 0.05
# Producto 'PVC JACQUARD': p-value = 0.10331095253418848 > 0.05
# Producto 'PVC TRANSPARENTE 12': p-value = 0.2825058948262949 > 0.05
# Producto 'RETAZOS POR KILO': Tamaño de muestra insuficiente.
# Producto 'RIBANA': p-value = 0.9036373617920683 > 0.05
# Producto 'RIBB FINO': p-value = 0.30102492304144346 > 0.05
# Producto 'RIBB PRETINA': p-value = 0.994373234880363 > 0.05
# Producto 'RIPSTOP CAMUFLAJE': p-value = 0.4943738375196323 > 0.05
# Producto 'RIPSTOP LISO': p-value = 0.16413141029258155 > 0.05
# Producto 'SABANA POPLIN INFANTIL': p-value = 0.5744039479195099 > 0.05
# Producto 'SATEN AMERICANO': p-value = 0.13347353153161845 > 0.05
# Producto 'SATEN CREPE ESTAMPADO': p-value = 0.13484761450530663 > 0.05
# Producto 'SATEN ELIE': Tamaño de muestra insuficiente.
# Producto 'SATEN ESTAMPADO': p-value = 0.9891217146861472 > 0.05
# Producto 'SATEN ESTAMPADO ELUNEY': p-value = 0.7262891258416453 > 0.05
# Producto 'SATEN ISADORA': p-value = 0.7817007307936006 > 0.05
# Producto 'SATEN ITALIANO': p-value = 0.1281294264759802 > 0.05
# Producto 'SATEN POLY': p-value = 0.9910536746387383 > 0.05
# Producto 'SATEN RAYAS AR L': p-value = 0.4787473326290909 > 0.05
# Producto 'SATEN RAYAS AR XL': p-value = 0.9813374718065258 > 0.05
# Producto 'SATEN RAYAS BN XL': p-value = 0.9930588954663325 > 0.05
# Producto 'SATEN RAYAS RB XL': Tamaño de muestra insuficiente.
# Producto 'SATEN SPANDEX': p-value = 0.09667741540543084 > 0.05
# Producto 'SATEN VALENTINO': p-value = 0.353851338510875 > 0.05
# Producto 'SEDA PIEL DURAZNO ESTAMPADO': p-value = 1.0 > 0.05
# Producto 'SEDA ZUHAIR': p-value = 0.15744691306544883 > 0.05
# Producto 'SUECIA LISO': p-value = 0.1443175682524992 > 0.05
# Producto 'SUPLEX ESTAMPADO': p-value = 0.11680158585549827 > 0.05
# Producto 'TACTEL GAMUZADO': p-value = 0.1606816158912719 > 0.05
# Producto 'TAFETA': p-value = 0.6776930398677488 > 0.05
# Producto 'TAFETA ELUNEY': p-value = 0.9896293674827543 > 0.05
# Producto 'TAFETA GAMUZADA': Tamaño de muestra insuficiente.
# Producto 'TAFETA SHANTUNG': p-value = 0.6145833942808928 > 0.05
# Producto 'TAPIZMEL ANTIDESLIZANTE': p-value = 0.166297791741853 > 0.05
# Producto 'TASLAN IMPERMEABLE': p-value = 0.05528711984058348 > 0.05
# Producto 'TERCIOPELO': p-value = 0.0647080120163395 > 0.05
# Producto 'TERCIOPELO AGATHA': p-value = 0.09032460014773114 > 0.05
# Producto 'TNT 60': p-value = 0.24221519845289696 > 0.05
# Producto 'TNT 70': p-value = 0.4684362008484555 > 0.05
# Producto 'TNT EMBOSS': p-value = 0.14286022895139588 > 0.05
# Producto 'TRICOT SASTRE': Tamaño de muestra insuficiente.
# Producto 'TROPICAL CORTINAS': Tamaño de muestra insuficiente.
# Producto 'TROPICAL MECANICO LISO': p-value = 0.27650796827886426 > 0.05
# Producto 'TUL CON PERLAS': p-value = 0.11377043271149201 > 0.05
# Producto 'TUL DE ARMAR SOFT': p-value = 0.8375830965150843 > 0.05
# Producto 'TUL DE ARMAR XL': p-value = 0.06335869067350682 > 0.05
# Producto 'TUL FENDI': p-value = 0.05898604481152256 > 0.05
# Producto 'TUL GABBANA': p-value = 0.05462589903379385 > 0.05
# Producto 'TUL GALLIANO': p-value = 0.12084570585342091 > 0.05
# Producto 'TUL GIBRE': p-value = 0.5303172281651894 > 0.05
# Producto 'TUL GLITTER': p-value = 0.18990708333222645 > 0.05
# Producto 'TUL HERMES': Tamaño de muestra insuficiente.
# Producto 'TUL ILUSION SOFT': p-value = 0.08745535061832427 > 0.05
# Producto 'TUL ISABELLA': p-value = 0.07394200405593669 > 0.05
# Producto 'TUL LAMINADO': p-value = 0.0749210240621406 > 0.05
# Producto 'TUL PROENZA': p-value = 0.07100749774887 > 0.05
# Producto 'TUL SOPHIA': p-value = 0.288987111655745 > 0.05
# Producto 'TUL VERSACE': p-value = 0.3965902546043675 > 0.05
# Producto 'TWILL STRETCH': p-value = 0.932377498303472 > 0.05
# Producto 'VISCOLYCRA ESTAMPADO': p-value = 0.3253924900997792 > 0.05
# Producto 'VOLADOS LOLA': p-value = 0.05546071177372164 > 0.05
# Producto 'ACETATO SPANDEX': p-value = 0.11515080601918787 > 0.05
# Producto 'BATISTA CALADA LUREX': Tamaño de muestra insuficiente.
# Producto 'BATISTA RAYAS VENTANA': Tamaño de muestra insuficiente.
# Producto 'BROCATO NIMA': Tamaño de muestra insuficiente.
# Producto 'CARRE': p-value = 0.09319884311264309 > 0.05
# Producto 'CASHMERE INGLES OXFORD': p-value = 0.7347072621070445 > 0.05
# Producto 'CASHMERE OJO DE PERDIZ': p-value = 0.8474167737743517 > 0.05
# Producto 'CASHMERE SATINADO LUREX': p-value = 0.7383303231067109 > 0.05
# Producto 'CASHMERE TWO TONE': p-value = 0.9918960744211242 > 0.05
# Producto 'CESPED SINTETICO': p-value = 0.2941250149159704 > 0.05
# Producto 'CREPE MOSS ESTAMPADO ELUNEY': Tamaño de muestra insuficiente.
# Producto 'CREPE SEDA DUPIONI': Tamaño de muestra insuficiente.
# Producto 'CUERINA MOTEADA': p-value = 0.942043385870316 > 0.05
# Producto 'ENCAJE ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'FIBRANA SATINADA': Tamaño de muestra insuficiente.
# Producto 'FRANELA DOMESTICA': Tamaño de muestra insuficiente.
# Producto 'GASA 3D ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'GASA BAMBULA': Tamaño de muestra insuficiente.
# Producto 'GASA DOBLE': p-value = 0.4154979262968558 > 0.05
# Producto 'GASA EREVAN': p-value = 0.12371837911205752 > 0.05
# Producto 'GASA LAMINADA': Tamaño de muestra insuficiente.
# Producto 'GASA SATIN DEGRADE': Tamaño de muestra insuficiente.
# Producto 'GUIPIURE VERSACE': Tamaño de muestra insuficiente.
# Producto 'JACQUARD SPANDEX': p-value = 0.9917675643575156 > 0.05
# Producto 'LYCRA LAMINADO': Tamaño de muestra insuficiente.
# Producto 'MICRO PERFORADO': p-value = 0.7385813067904246 > 0.05
# Producto 'MICROTUL DEGRADE': p-value = 0.1978456756515597 > 0.05
# Producto 'ORGANZA ORIENTE LISO': p-value = 0.05955006807649236 > 0.05
# Producto 'ORGANZA VERSACE': Tamaño de muestra insuficiente.
# Producto 'ORGANZA XXL': p-value = 0.7587749058090875 > 0.05
# Producto 'PANA CALISA': Tamaño de muestra insuficiente.
# Producto 'PANHO CHEVIOT': Tamaño de muestra insuficiente.
# Producto 'RETACERIA SASTRERIA': p-value = 0.27097951940871684 > 0.05
# Producto 'SEDA PIEL DURAZNO LISO': p-value = 0.5020664956626408 > 0.05
# Producto 'SHANTUNG ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'TNT ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'BENGALINA CLOQUE': Tamaño de muestra insuficiente.
# Producto 'BOAL LABRADO': Tamaño de muestra insuficiente.
# Producto 'CANVAS GRECIA ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'CHENILLE PANAMA': Tamaño de muestra insuficiente.
# Producto 'CORTINA CINTA ARMADORA': Tamaño de muestra insuficiente.
# Producto 'HILOS PANAMA ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'JERSEY POLIVISCOSA': Tamaño de muestra insuficiente.
# Producto 'MALLA ESTAMPADO': p-value = 0.32897186853186544 > 0.05
# Producto 'MATELASSE COTTON': p-value = 0.9286285312056639 > 0.05
# Producto 'ORGANZA SOPHIA': Tamaño de muestra insuficiente.
# Producto 'PANA SASTRE': p-value = 0.9973208246647821 > 0.05
# Producto 'PANHO SINTETICO ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'PRINCIPE DE GALES RUSTICO': Tamaño de muestra insuficiente.
# Producto 'PVC RIGIDO': Tamaño de muestra insuficiente.
# Producto 'SATEN RAYAS AA L': Tamaño de muestra insuficiente.
# Producto 'SATIN IMPERMEABLE': p-value = 0.998632650014046 > 0.05
# Producto 'TERCIOPELO ESTAMPADO': p-value = 0.8424896535689061 > 0.05
# Producto 'VELBOA SOFT': p-value = 0.10942074508557986 > 0.05
# Producto 'CANVAS ESTAMPADO ELUNEY': Tamaño de muestra insuficiente.
# Producto 'CASHMERE FRANCES': Tamaño de muestra insuficiente.
# Producto 'CORTINA RIEL': Tamaño de muestra insuficiente.
# Producto 'JERSEY ELIZABETH INFANTIL': Tamaño de muestra insuficiente.
# Producto 'MANTELERIA HILO ESTAMPADO': p-value = 0.11103333840756807 > 0.05
# Producto 'MATELASSE EMBOSS': Tamaño de muestra insuficiente.
# Producto 'MICRO JACQUARD': Tamaño de muestra insuficiente.
# Producto 'SARGA ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'TERCIOPELO HERMES': Tamaño de muestra insuficiente.
# Producto 'TERCIOPELO TWO TONE': p-value = 0.08850326522027396 > 0.05
# Producto 'VIYELA ESPIGA LISO': Tamaño de muestra insuficiente.
# Producto 'ANTISOLAR DEGRADE': Tamaño de muestra insuficiente.
# Producto 'BATISTA': Tamaño de muestra insuficiente.
# Producto 'BATISTA LISO': Tamaño de muestra insuficiente.
# Producto 'BENGALINA FLOCKING': Tamaño de muestra insuficiente.
# Producto 'BROCATO RUSTICO': Tamaño de muestra insuficiente.
# Producto 'CHENILLE RUSTICO': Tamaño de muestra insuficiente.
# Producto 'CLOQUE RAYAS': Tamaño de muestra insuficiente.
# Producto 'GABARDINA EMBOSS SP': Tamaño de muestra insuficiente.
# Producto 'GAMUZA SHAMOA': Tamaño de muestra insuficiente.
# Producto 'HILOS PANAMA PREMIUM': p-value = 0.8976924305788488 > 0.05
# Producto 'JERSEY ESTAMPADO LANILLADO': Tamaño de muestra insuficiente.
# Producto 'LINO CREPE': Tamaño de muestra insuficiente.
# Producto 'LYCRA TEXTURIZADA': p-value = 0.41903288997617727 > 0.05
# Producto 'MALLA LISO ELUNEY': Tamaño de muestra insuficiente.
# Producto 'MALLA LUREX ESTAMPADA': Tamaño de muestra insuficiente.
# Producto 'MICRO FOURWAY ESTAMPADO': p-value = 0.6315085284769758 > 0.05
# Producto 'PANA ROYAL WR': Tamaño de muestra insuficiente.
# Producto 'PERCAL BORDADO': Tamaño de muestra insuficiente.
# Producto 'PERCAL NAVIDAD': Tamaño de muestra insuficiente.
# Producto 'SATEN LAMINADO': Tamaño de muestra insuficiente.
# Producto 'SATEN OFERTA': Tamaño de muestra insuficiente.
# Producto 'CASHMERE ITALIANO': Tamaño de muestra insuficiente.
# Producto 'CREPE CHENILLA PLISSE': Tamaño de muestra insuficiente.
# Producto 'CUERINA SPANDEX': Tamaño de muestra insuficiente.
# Producto 'GABARDINA COTTON KABIL SP': Tamaño de muestra insuficiente.
# Producto 'GABARDINA SCUBA': Tamaño de muestra insuficiente.
# Producto 'GROSS MADRID': Tamaño de muestra insuficiente.
# Producto 'GUIPIURE CHLOE': p-value = 0.4663591597811922 > 0.05
# Producto 'JERSEY CATIONIC II': Tamaño de muestra insuficiente.
# Producto 'MALLA ELUNEY': Tamaño de muestra insuficiente.
# Producto 'MOLETON FRISA': Tamaño de muestra insuficiente.
# Producto 'PAILLETTE SOPHIA': p-value = 0.9894702954697572 > 0.05
# Producto 'PERCAL TC ESTAMPADO L': Tamaño de muestra insuficiente.
# Producto 'RANDA NOVIA': p-value = 0.5906798760367901 > 0.05
# Producto 'SATEN DRAPEADO': p-value = 0.385232544744079 > 0.05
# Producto 'SCUBA CREPE LISO': Tamaño de muestra insuficiente.
# Producto 'TAFETA DEVORE': p-value = 0.12619573889139424 > 0.05
# Producto 'BAMBULA LUREX': Tamaño de muestra insuficiente.
# Producto 'CUERINA VINTAGE': Tamaño de muestra insuficiente.
# Producto 'ECO CUERO': p-value = 0.6464241847535355 > 0.05
# Producto 'FIBRANA LINO': p-value = 0.25829680678116607 > 0.05
# Producto 'HILOS FIL A FIL RAYAS': Tamaño de muestra insuficiente.
# Producto 'MORLEY LISO': p-value = 0.5828180835563634 > 0.05
# Producto 'ORGANZA TWO TONE': Tamaño de muestra insuficiente.
# Producto 'SUECIA DELUXE': Tamaño de muestra insuficiente.
# Producto 'TAFETA PIEL DURAZNO LISO': Tamaño de muestra insuficiente.
# Producto 'BOAL LAMINADO': Tamaño de muestra insuficiente.
# Producto 'CHENILLE DRAPE RAYAS': Tamaño de muestra insuficiente.
# Producto 'FIBRANA LINO SP': p-value = 0.14127816180362845 > 0.05
# Producto 'GASA BAMBULA BORDADO': Tamaño de muestra insuficiente.
# Producto 'GASA STRIPES ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'LAME TORNASOL': Tamaño de muestra insuficiente.
# Producto 'POLAR VELBOA EMBOSS XL': Tamaño de muestra insuficiente.
# Producto 'TACTEL ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'TAFETA TORNASOL': Tamaño de muestra insuficiente.
# Producto 'BENGALINA RAYON': Tamaño de muestra insuficiente.
# Producto 'CASHMERE ESPIGA SOFT': Tamaño de muestra insuficiente.
# Producto 'GASA DOBLE ESPEJO': Tamaño de muestra insuficiente.
# Producto 'MUSELINA SPANDEX ESTAMPADA': p-value = 0.24649492503590653 > 0.05
# Producto 'ORGANZA LAMINADO': Tamaño de muestra insuficiente.
# Producto 'POPELINA ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'SATEN DOBLE OPACO': Tamaño de muestra insuficiente.
# Producto 'SATEN EMBOSS': Tamaño de muestra insuficiente.
# Producto 'CREPE MOSS SPANDEX': p-value = 0.3427895716021092 > 0.05
# Producto 'MALLA SPORT ZIG ZAG': Tamaño de muestra insuficiente.
# Producto 'PERCAL PILAR': Tamaño de muestra insuficiente.
# Producto 'SATEN MILAN': p-value = 0.8374205057478256 > 0.05
# Producto 'TUL PLUMETI LOLA': p-value = 0.4897035600340777 > 0.05
# Producto 'CUERINA ELUNEY': Tamaño de muestra insuficiente.
# Producto 'OXFORD LISO': Tamaño de muestra insuficiente.
# Producto 'VIYELA BORDADA': Tamaño de muestra insuficiente.
# Producto 'CASHMERE ESPIGA RAYAS': Tamaño de muestra insuficiente.
# Producto 'TERCIOPELO LYON': Tamaño de muestra insuficiente.
# Producto 'GASA BAMBULA ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'PANA SUECIA ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'SUECIA EMBOSS ESTAMPADO': p-value = 0.0901647696733453 > 0.05
# Producto 'GABARDINA LABRADA SP': Tamaño de muestra insuficiente.
# Producto 'GASA GAMUZA LISO': Tamaño de muestra insuficiente.
# Producto 'GROSS SATINADO': Tamaño de muestra insuficiente.
# Producto 'SATEN RAYAS AA XL': Tamaño de muestra insuficiente.
# Producto 'CORDEROY SPANDEX': Tamaño de muestra insuficiente.
# Producto 'MATELASSE GAMUZADO': Tamaño de muestra insuficiente.
# Producto 'OXFORD PLISE': Tamaño de muestra insuficiente.
# Producto 'PAILLETTE FENDI': Tamaño de muestra insuficiente.
# Producto 'PAILLETTE VERSACE': p-value = 0.4312307228679337 > 0.05
# Producto 'PANHO LANA JASPEADO': Tamaño de muestra insuficiente.
# Producto 'TAFETA RUSTICA': Tamaño de muestra insuficiente.
# Producto 'TUL TORNASOL': p-value = 0.992917042141691 > 0.05
# Producto 'CHEVIOT MICRO': Tamaño de muestra insuficiente.
# Producto 'FIBRANA LINO ESTAMPADO': p-value = 0.5074638498287556 > 0.05
# Producto 'POLAR ACANALADO': Tamaño de muestra insuficiente.
# Producto 'SHANTUNG RUSTICO': Tamaño de muestra insuficiente.
# Producto 'TNT 20': Tamaño de muestra insuficiente.
# Producto 'TNT 30': Tamaño de muestra insuficiente.
# Producto 'TWEED ESPIGA BOUCLE': Tamaño de muestra insuficiente.
# Producto 'CREPE MILENA': p-value = 0.39105124453223283 > 0.05
# Producto 'DIOLEN LISO ELUNEY': Tamaño de muestra insuficiente.
# Producto 'SEDA AMBAR': p-value = 0.17855072194211435 > 0.05
# Producto 'BAMBULA BORDADO': Tamaño de muestra insuficiente.
# Producto 'JERSEY CON APLIQUES': Tamaño de muestra insuficiente.
# Producto 'POPLIN CUADRILLE': p-value = 0.7546928298852302 > 0.05
# Producto 'ANTISOLAR NOGAL': p-value = 0.3038915161538473 > 0.05
# Producto 'DRY FIT OLYMPIC': p-value = 0.47201322478429414 > 0.05
# Producto 'GASA DEVORE': p-value = 0.9990418775285584 > 0.05
# Producto 'GASA PLUMETI': p-value = 0.645949854086003 > 0.05
# Producto 'IMPERMEABLE PRADA LISO': Tamaño de muestra insuficiente.
# Producto 'MALLA PUK ': p-value = 0.5735647668132082 > 0.05
# Producto 'MORLEY SOFT': p-value = 0.06577268543457127 > 0.05
# Producto 'RANDA RUSTICA': Tamaño de muestra insuficiente.
# Producto 'SATEN RAYAS RB L': Tamaño de muestra insuficiente.
# Producto 'TWEED CELINA': p-value = 0.9919204052680589 > 0.05
# Producto 'TWEED LUNA': p-value = 0.42971481295447966 > 0.05
# Producto 'TWILL PREMIUM': p-value = 0.17260833300847067 > 0.05
# Producto 'GASA DRAPEADO': Tamaño de muestra insuficiente.
# Producto 'IMPERMEABLE PRADA PLISADO': Tamaño de muestra insuficiente.
# Producto 'MICRO TUL STRIPES': p-value = 0.23179518823176637 > 0.05
# Producto 'MUSELINA PLISADA': p-value = 0.5601273844571478 > 0.05
# Producto 'TWILL ADA': p-value = 0.7293741322101869 > 0.05
# Producto 'SUECIA ATIGRADO WR': Tamaño de muestra insuficiente.
# Producto 'TUL GLITTER CORAZONES': p-value = 0.1541631411593638 > 0.05
# Producto 'FORRERIA PARA COLCHON': Tamaño de muestra insuficiente.
# Producto 'CREPE CEY': Tamaño de muestra insuficiente.
# Producto 'GIBRE SOPHIA': Tamaño de muestra insuficiente.
# Producto 'GUIPIURE CRISTAL': Tamaño de muestra insuficiente.
# Producto 'HILOS RUSTICO ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'MICRO GLITTER': Tamaño de muestra insuficiente.
# Producto 'MICRO TUL ISADORA': Tamaño de muestra insuficiente.
# Producto 'MICRO TUL LAMINADO': Tamaño de muestra insuficiente.
# Producto 'ORGANDI GLITTER': Tamaño de muestra insuficiente.
# Producto 'REDECILLA SOPHIA': Tamaño de muestra insuficiente.
# Producto 'TAFETA MEMORY': Tamaño de muestra insuficiente.
# Producto 'CREPE DRAPE': Tamaño de muestra insuficiente.
# Producto 'DRY HEXA': Tamaño de muestra insuficiente.
# Producto 'LYCRA FOIL': Tamaño de muestra insuficiente.
# Producto 'MALLA CRISTAL': Tamaño de muestra insuficiente.
# Producto 'MOLETON POLY TERRY ': Tamaño de muestra insuficiente.
# Producto 'MORLEY LUREX': Tamaño de muestra insuficiente.
# Producto 'PLISSE TISSU': Tamaño de muestra insuficiente.
# Producto 'POLAR VELBOA EMBOSS XXL': Tamaño de muestra insuficiente.
# Producto 'POLAR VELBOA XXL': Tamaño de muestra insuficiente.
# Producto 'RIBB LIVIANO RAYAS': Tamaño de muestra insuficiente.
# Producto 'SCUBA CREPE LIGHT': Tamaño de muestra insuficiente.
# Producto 'TRICOT SASTRE SPANDEX': Tamaño de muestra insuficiente.
# Producto 'DENIM LUREX': Tamaño de muestra insuficiente.
# Producto 'MICRO CHANTILLY': Tamaño de muestra insuficiente.
# Producto 'MORLEY WAFLE': Tamaño de muestra insuficiente.
# Producto 'SEDA ESTAMPADA': Tamaño de muestra insuficiente.
# Producto 'TUL PLUMETI CHLOE': Tamaño de muestra insuficiente.
# Producto 'GUIPIURE REDECILLA': Tamaño de muestra insuficiente.
# Producto 'DRY JACQUARD': Tamaño de muestra insuficiente.
# Producto 'GAMUZA BORDADO': Tamaño de muestra insuficiente.
# Producto 'GASA MILAN': Tamaño de muestra insuficiente.
# Producto 'IMPERMEABLE CAMUFLAJE': Tamaño de muestra insuficiente.
# Producto 'MOLETON TERRY MELANGE': Tamaño de muestra insuficiente.
# Producto 'TWILL STRETCH ESTAMPADO': Tamaño de muestra insuficiente.
# Producto 'ORGANZA PLISSE': Tamaño de muestra insuficiente.
# Producto 'ORGANZA SEDA ISADORA': Tamaño de muestra insuficiente.
# Producto 'PLISSE PLUMETI': Tamaño de muestra insuficiente.
# Producto 'SATEN EVA': Tamaño de muestra insuficiente.
# Producto 'SATEN LUREX': Tamaño de muestra insuficiente.
# Producto 'POPLIN CUADRILLE LOLA': Tamaño de muestra insuficiente.
# Producto 'POPLIN OXFORD LOLA': Tamaño de muestra insuficiente.
# Producto 'POPLIN RAYAS LOLA': Tamaño de muestra insuficiente.
# Producto 'DRY HEXAGONO': Tamaño de muestra insuficiente.
# Producto 'FIBRANA CREPE ESTAMPADA': Tamaño de muestra insuficiente.
# Producto 'MORLEY LOLA': Tamaño de muestra insuficiente.

# %%
df_stationary
# Out:
#            mes            descrip  venta
# 1      2021-02            ACETATO  16580
# 544    2021-03            ACETATO  14959
# 1101   2021-04            ACETATO  31214
# 1665   2021-05            ACETATO  56038
# 2197   2021-06            ACETATO  31245
# ...        ...                ...    ...
# 15357  2023-04  TUL GLITTER MOTAS      8
# 15927  2023-05  TUL GLITTER MOTAS     13
# 16493  2023-06  TUL GLITTER MOTAS      6
# 17070  2023-07  TUL GLITTER MOTAS      8
# 17640  2023-08  TUL GLITTER MOTAS     20
#
# [9817 rows x 3 columns]

# %% [markdown]
# # Esta parte no funciona

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Suponiendo que tienes tu DataFrame llamado df_stationary

# Crear un DataFrame de fechas para el período de predicción
fechas_prediccion = pd.date_range(start='2023-09-01', end='2024-09-01', freq='M')

# Crear un diccionario para almacenar las predicciones de cada producto
predicciones = {}

# Iterar sobre los productos en df_stationary
for product in df_stationary['descrip'].unique():
    df_product = df_stationary[df_stationary['descrip'] == product]

    # Convertir la columna 'venta' a tipo numérico si no lo es
    df_product['venta'] = pd.to_numeric(df_product['venta'], errors='coerce')

    # Eliminar filas con valores nulos resultantes de la conversión
    df_product = df_product.dropna(subset=['venta'])

    # Crear una serie temporal con fechas como índice y frecuencia mensual
    serie_temporal = pd.Series(df_product['venta'].values, index=pd.to_datetime(df_product['mes']))

    # Ajustar un modelo ARIMA (p, d, q) con d=0
    modelo_arima = ARIMA(serie_temporal, order=(1, 0, 1))
    resultado_arima = modelo_arima.fit()

    # Realizar predicciones para el período 2023-09 al 2024-09
    predicciones[product] = resultado_arima.get_forecast(steps=len(fechas_prediccion))
    predicciones[product] = predicciones[product].predicted_mean.round().astype(int)

# Crear un DataFrame con las predicciones
df_predicciones = pd.DataFrame(predicciones)

# Replicar las fechas de predicción para cada producto
df_predicciones['mes'] = fechas_prediccion.strftime('%Y-%m').tolist() * len(df_predicciones)

# Reorganizar las columnas para que coincidan con el formato deseado
df_predicciones = df_predicciones[['mes'] + list(df_predicciones.columns[:-1])]

# Imprimir el DataFrame con las predicciones
print(df_predicciones)
# Out:
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# ...
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\4273590738.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 37
#      34 df_predicciones = pd.DataFrame(predicciones)
#      36 # Replicar las fechas de predicción para cada producto
# ---> 37 df_predicciones['mes'] = fechas_prediccion.strftime('%Y-%m').tolist() * len(df_predicciones)
#      39 # Reorganizar las columnas para que coincidan con el formato deseado
#      40 df_predicciones = df_predicciones[['mes'] + list(df_predicciones.columns[:-1])]
#
# File c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3960, in DataFrame.__setitem__(self, key, value)
#    3957     self._setitem_array([key], value)
#    3958 else:
#    3959     # set column
# -> 3960     self._set_item(key, value)
#
# File c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4153, in DataFrame._set_item(self, key, value)
#    4143 def _set_item(self, key, value) -> None:
#    4144     """
#    4145     Add series to DataFrame in specified column.
#    4146
#    (...)
#    4151     ensure homogeneity.
#    4152     """
# -> 4153     value = self._sanitize_column(value)
#    4155     if (
#    4156         key in self.columns
#    4157         and value.ndim == 1
#    4158         and not is_extension_array_dtype(value)
#    4159     ):
#    4160         # broadcast across multiple columns if necessary
#    4161         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4880, in DataFrame._sanitize_column(self, value)
#    4877     return _reindex_for_setitem(Series(value), self.index)
#    4879 if is_list_like(value):
# -> 4880     com.require_length_match(value, self.index)
#    4881 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\common.py:576, in require_length_match(data, index)
#     572 """
#     573 Check the length of data matches the length of the index.
#     574 """
#     575 if len(data) != len(index):
# --> 576     raise ValueError(
#     577         "Length of values "
#     578         f"({len(data)}) "
#     579         "does not match length of index "
#     580         f"({len(index)})"
#     581     )
#
# ValueError: Length of values (564) does not match length of index (47)

# %%
df_predicciones = pd.DataFrame(predicciones)

# Replicar las fechas de predicción para cada fila (no para cada producto)
df_predicciones['mes'] = fechas_prediccion.repeat(len(df_predicciones) // len(fechas_prediccion) + 1)[:len(df_predicciones)].strftime('%Y-%m')

# Reorganizar las columnas para que coincidan con el formato deseado
df_predicciones = df_predicciones[['mes'] + list(df_predicciones.columns[:-1])]

# %%
df_predicciones = df_predicciones.transpose()

# Imprimir el DataFrame transpuesto
df_predicciones
# Out:
#                          2023-09-01 00:00:00 2023-10-01 00:00:00
# mes                                  2023-09             2023-09  \
# ACETATO                               8784.0             15501.0
# ALEMANISCO                               NaN                 NaN
# ALEMANISCO PREMIUN                      34.0                35.0
# ANTISOLAR                             1162.0              1195.0
# ...                                      ...                 ...
# SARGA VENETA                           219.0               146.0
# MUSELINA SPANDEX PLISADA                 7.0                 9.0
# PIED DE POULE SOFT                      45.0                44.0
# TUL GLITTER ESTRELLAS                   36.0                40.0
# TUL GLITTER MOTAS                       27.0                26.0
#
#                          2023-11-01 00:00:00 2023-12-01 00:00:00
# mes                                  2023-09             2023-09  \
# ACETATO                              18765.0             20350.0
# ALEMANISCO                               NaN                 NaN
# ALEMANISCO PREMIUN                      35.0                35.0
# ANTISOLAR                             1213.0              1223.0
# ...                                      ...                 ...
# SARGA VENETA                           133.0               131.0
# MUSELINA SPANDEX PLISADA                10.0                10.0
# PIED DE POULE SOFT                      43.0                42.0
# TUL GLITTER ESTRELLAS                   43.0                45.0
# TUL GLITTER MOTAS                       26.0                26.0
#
#                          2024-01-01 00:00:00 2024-02-01 00:00:00
# mes                                  2023-10             2023-10  \
# ACETATO                              21120.0             21495.0
# ALEMANISCO                               NaN                 NaN
# ALEMANISCO PREMIUN                      35.0                35.0
# ANTISOLAR                             1229.0              1232.0
# ...                                      ...                 ...
# SARGA VENETA                           130.0               130.0
# MUSELINA SPANDEX PLISADA                10.0                10.0
# PIED DE POULE SOFT                      42.0                41.0
# TUL GLITTER ESTRELLAS                   47.0                48.0
# TUL GLITTER MOTAS                       26.0                26.0
#
#                          2024-03-01 00:00:00 2024-04-01 00:00:00
# mes                                  2023-10             2023-10  \
# ACETATO                              21676.0             21765.0
# ALEMANISCO                               NaN                 NaN
# ALEMANISCO PREMIUN                      35.0                35.0
# ANTISOLAR                             1234.0              1235.0
# ...                                      ...                 ...
# SARGA VENETA                           130.0               130.0
# MUSELINA SPANDEX PLISADA                10.0                10.0
# PIED DE POULE SOFT                      41.0                41.0
# TUL GLITTER ESTRELLAS                   49.0                49.0
# TUL GLITTER MOTAS                       26.0                26.0
#
#                          2024-05-01 00:00:00 2024-06-01 00:00:00  ...
# mes                                  2023-11             2023-11  ...  \
# ACETATO                              21807.0             21828.0  ...
# ALEMANISCO                               NaN                 NaN  ...
# ALEMANISCO PREMIUN                      35.0                35.0  ...
# ANTISOLAR                             1236.0              1236.0  ...
# ...                                      ...                 ...  ...
# SARGA VENETA                           130.0               130.0  ...
# MUSELINA SPANDEX PLISADA                10.0                10.0  ...
# PIED DE POULE SOFT                      41.0                41.0  ...
# TUL GLITTER ESTRELLAS                   49.0                50.0  ...
# TUL GLITTER MOTAS                       26.0                26.0  ...
#
#                                41 2023-06-01 00:00:00 2023-07-01 00:00:00
# mes                       2024-06             2024-06             2024-06  \
# ACETATO                       NaN                 NaN                 NaN
# ALEMANISCO                    NaN                 NaN                 NaN
# ALEMANISCO PREMIUN            NaN                 NaN                 NaN
# ANTISOLAR                     NaN                 NaN                 NaN
# ...                           ...                 ...                 ...
# SARGA VENETA                  NaN                 NaN                 NaN
# MUSELINA SPANDEX PLISADA      NaN                 NaN                 NaN
# PIED DE POULE SOFT            NaN                 NaN                 NaN
# TUL GLITTER ESTRELLAS         NaN                 NaN                 NaN
# TUL GLITTER MOTAS             NaN                 NaN                 NaN
#
#                          2023-08-01 00:00:00       11       12       13
# mes                                  2024-07  2024-07  2024-07  2024-07  \
# ACETATO                                  NaN      NaN      NaN      NaN
# ALEMANISCO                               NaN      NaN      NaN      NaN
# ALEMANISCO PREMIUN                       NaN      NaN      NaN      NaN
# ANTISOLAR                                NaN      NaN      NaN      NaN
# ...                                      ...      ...      ...      ...
# SARGA VENETA                             NaN      NaN      NaN      NaN
# MUSELINA SPANDEX PLISADA                 NaN      NaN      NaN      NaN
# PIED DE POULE SOFT                       NaN      NaN      NaN      NaN
# TUL GLITTER ESTRELLAS                    NaN      NaN      NaN      NaN
# TUL GLITTER MOTAS                        NaN      NaN      NaN      NaN
#
#                                14       15       10
# mes                       2024-08  2024-08  2024-08
# ACETATO                       NaN      NaN      NaN
# ALEMANISCO                    NaN      NaN      NaN
# ALEMANISCO PREMIUN            NaN      NaN      NaN
# ANTISOLAR                     NaN      NaN      NaN
# ...                           ...      ...      ...
# SARGA VENETA                  NaN      NaN      NaN
# MUSELINA SPANDEX PLISADA      NaN      NaN      NaN
# PIED DE POULE SOFT            NaN      NaN      NaN
# TUL GLITTER ESTRELLAS         NaN      NaN      NaN
# TUL GLITTER MOTAS             NaN      NaN      NaN
#
# [370 rows x 47 columns]

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Crear un DataFrame de fechas para el período de predicción
fechas_prediccion = pd.date_range(start='2023-09-01', end='2024-09-01', freq='MS')

# Crear un diccionario para almacenar las predicciones de cada producto
predicciones = {}

# Iterar sobre los productos en df_product
for product in df_product['descrip'].unique():
    df_product_filtered = df_product[df_product['descrip'] == product]

    # Asegúrate de que 'venta' sea de tipo numérico
    df_product_filtered['venta'] = pd.to_numeric(df_product_filtered['venta'], errors='coerce')

    # Elimina filas con valores faltantes en 'venta'
    df_product_filtered = df_product_filtered.dropna(subset=['venta'])

    # Crear una serie temporal con fechas como índice
    serie_temporal = pd.Series(df_product_filtered['venta'].values, index=pd.to_datetime(df_product_filtered['mes']))

    # Ajustar un modelo ARIMA (p, d, q)
    modelo_arima = ARIMA(serie_temporal, order=(1, 1, 1))
    resultado_arima = modelo_arima.fit()

    # Realizar predicciones para el período 2023-09 al 2024-09
    predicciones[product] = resultado_arima.get_forecast(steps=len(fechas_prediccion))
    predicciones[product] = predicciones[product].predicted_mean.round().astype(int)

# Crear un DataFrame con las predicciones
df_predicciones = pd.DataFrame(predicciones)
df_predicciones['mes'] = fechas_prediccion.strftime('%Y-%m')

# Reorganizar las columnas para que coincidan con el formato deseado
df_predicciones = df_predicciones[['mes'] + list(df_predicciones.columns[:-1])]

# Crear una tabla resumen con la sumatoria de las ventas para cada producto a lo largo de un año
df_resumen_ventas = df_predicciones.groupby('mes').sum().reset_index()

# Imprimir el DataFrame con las predicciones
print("Predicciones para cada producto:")
df_predicciones
print("\nTabla resumen de ventas por mes:")
df_resumen_ventas
# Out:
# Predicciones para cada producto:
#
# Tabla resumen de ventas por mes:
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#         mes  TUL GLITTER MOTAS
# 0   2023-09                 25
# 1   2023-10                 27
# 2   2023-11                 27
# 3   2023-12                 28
# 4   2024-01                 28
# 5   2024-02                 28
# 6   2024-03                 28
# 7   2024-04                 28
# 8   2024-05                 28
# 9   2024-06                 28
# 10  2024-07                 28
# 11  2024-08                 28
# 12  2024-09                 28

# %% [markdown]
# # A partir de acá empieza a funcionar.

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA

# Supongamos que tienes un DataFrame llamado df_stationary con columnas 'mes', 'descrip', 'venta'

# Crear un DataFrame de fechas para el período de predicción
fechas_prediccion = pd.date_range(start='2023-09-01', end='2024-09-01', freq='MS')

# Crear un diccionario para almacenar las predicciones de cada producto
predicciones = {}

# Iterar sobre los productos en df_stationary
for product in df_stationary['descrip'].unique():
    df_product = df_stationary[df_stationary['descrip'] == product]

    # Asegúrate de que 'venta' sea de tipo numérico y elimina filas con valores faltantes
    df_product['venta'] = pd.to_numeric(df_product['venta'], errors='coerce')
    df_product = df_product.dropna(subset=['venta'])

    # Crear una serie temporal con fechas como índice
    serie_temporal = pd.Series(df_product['venta'].values, index=pd.to_datetime(df_product['mes']))

    # Ajustar un modelo ARIMA (p, d, q) con d=0 # Se usa 0 cuando los datos ya son estacionarios y se usa 1 cuando no
    modelo_arima = ARIMA(serie_temporal, order=(1, 0, 1))
    resultado_arima = modelo_arima.fit()

    # Realizar predicciones para el período 2023-09 al 2024-09
    predicciones[product] = resultado_arima.get_forecast(steps=len(fechas_prediccion)).predicted_mean.round().astype(int)

# Crear un DataFrame con las predicciones
df_predicciones = pd.DataFrame(predicciones)

# Crear una tabla resumen con la sumatoria de las predicciones para cada producto
df_resumen = df_predicciones.sum(axis=0).reset_index()
df_resumen.columns = ['descrip', 'ventas_2024']
# Out:
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning:
#
# Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning:
#
# No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning:
#
# No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# C:\Users\navo2\AppData\Local\Temp\ipykernel_26760\2703175597.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# c:\Users\navo2\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency MS will be used.
#
# ...
# 2024-04-01 00:00:00                 NaN  ...         46.0            2618.0
# 2024-05-01 00:00:00                 NaN  ...         46.0            2621.0
# 2024-06-01 00:00:00                 NaN  ...         46.0            2622.0
# 2024-07-01 00:00:00                 NaN  ...         46.0            2623.0
# 2024-08-01 00:00:00                 NaN  ...         46.0            2623.0
# 2024-09-01 00:00:00                 NaN  ...         46.0            2623.0
# 17                                  NaN  ...          NaN               NaN
# 18                                  NaN  ...          NaN               NaN
# 19                                  NaN  ...          NaN               NaN
# 20                                  NaN  ...          NaN               NaN
# 21                                  3.0  ...          NaN               NaN
# 22                                  3.0  ...          NaN               NaN
# 23                                  3.0  ...          NaN               NaN
# 24                                  3.0  ...          NaN               NaN
# 25                                  3.0  ...          NaN               NaN
# 26                                  3.0  ...          NaN               NaN
# 27                                  3.0  ...          NaN               NaN
# 28                                  3.0  ...          NaN               NaN
# 29                                  3.0  ...          NaN               NaN
# 30                                  3.0  ...          NaN               NaN
# 31                                  3.0  ...          NaN               NaN
# 32                                  3.0  ...          NaN               NaN
# 33                                  3.0  ...          NaN               NaN
# 16                                  NaN  ...          NaN               NaN
# 34                                  NaN  ...          NaN               NaN
# 35                                  NaN  ...          NaN               NaN
# 36                                  NaN  ...          NaN               NaN
# 37                                  NaN  ...          NaN               NaN
# 38                                  NaN  ...          NaN               NaN
# 39                                  NaN  ...          NaN               NaN
# 40                                  NaN  ...          NaN               NaN
# 41                                  NaN  ...          NaN               NaN
# 42                                  NaN  ...          NaN               NaN
# 2023-06-01 00:00:00                 NaN  ...          NaN               NaN
# 2023-07-01 00:00:00                 NaN  ...          NaN               NaN
# 2023-08-01 00:00:00                 NaN  ...          NaN               NaN
# 11                                  NaN  ...          NaN               NaN
# 12                                  NaN  ...          NaN               NaN
# 13                                  NaN  ...          NaN               NaN
# 14                                  NaN  ...          NaN               NaN
# 15                                  NaN  ...          NaN               NaN
# 10                                  NaN  ...          NaN               NaN
#
#                      NIDO DE ABEJA  PAILLETTE  PROENZA  PANA SHERPA
# 2023-09-01 00:00:00           30.0                 NaN       1364.0  \
# 2023-10-01 00:00:00           33.0                 NaN       1331.0
# 2023-11-01 00:00:00           35.0                 NaN       1305.0
# 2023-12-01 00:00:00           36.0                 NaN       1286.0
# 2024-01-01 00:00:00           38.0                 NaN       1271.0
# 2024-02-01 00:00:00           39.0                 NaN       1259.0
# 2024-03-01 00:00:00           39.0                 NaN       1250.0
# 2024-04-01 00:00:00           40.0                 NaN       1243.0
# 2024-05-01 00:00:00           40.0                 NaN       1238.0
# 2024-06-01 00:00:00           41.0                 NaN       1234.0
# 2024-07-01 00:00:00           41.0                 NaN       1231.0
# 2024-08-01 00:00:00           41.0                 NaN       1229.0
# 2024-09-01 00:00:00           42.0                 NaN       1227.0
# 17                             NaN                 7.0          NaN
# 18                             NaN                 7.0          NaN
# 19                             NaN                 7.0          NaN
# 20                             NaN                 7.0          NaN
# 21                             NaN                 7.0          NaN
# 22                             NaN                 7.0          NaN
# 23                             NaN                 7.0          NaN
# 24                             NaN                 NaN          NaN
# 25                             NaN                 NaN          NaN
# 26                             NaN                 NaN          NaN
# 27                             NaN                 NaN          NaN
# 28                             NaN                 NaN          NaN
# 29                             NaN                 NaN          NaN
# 30                             NaN                 NaN          NaN
# 31                             NaN                 NaN          NaN
# 32                             NaN                 NaN          NaN
# 33                             NaN                 NaN          NaN
# 16                             NaN                 7.0          NaN
# 34                             NaN                 NaN          NaN
# 35                             NaN                 NaN          NaN
# 36                             NaN                 NaN          NaN
# 37                             NaN                 NaN          NaN
# 38                             NaN                 NaN          NaN
# 39                             NaN                 NaN          NaN
# 40                             NaN                 NaN          NaN
# 41                             NaN                 NaN          NaN
# 42                             NaN                 NaN          NaN
# 2023-06-01 00:00:00            NaN                 NaN          NaN
# 2023-07-01 00:00:00            NaN                 NaN          NaN
# 2023-08-01 00:00:00            NaN                 NaN          NaN
# 11                             NaN                 5.0          NaN
# 12                             NaN                 6.0          NaN
# 13                             NaN                 7.0          NaN
# 14                             NaN                 7.0          NaN
# 15                             NaN                 7.0          NaN
# 10                             NaN                 NaN          NaN
#
#                      SARGA VENETA  MUSELINA SPANDEX PLISADA
# 2023-09-01 00:00:00         219.0                       7.0  \
# 2023-10-01 00:00:00         146.0                       9.0
# 2023-11-01 00:00:00         133.0                      10.0
# 2023-12-01 00:00:00         131.0                      10.0
# 2024-01-01 00:00:00         130.0                      10.0
# 2024-02-01 00:00:00         130.0                      10.0
# 2024-03-01 00:00:00         130.0                      10.0
# 2024-04-01 00:00:00         130.0                      10.0
# 2024-05-01 00:00:00         130.0                      10.0
# 2024-06-01 00:00:00         130.0                      10.0
# 2024-07-01 00:00:00         130.0                      10.0
# 2024-08-01 00:00:00         130.0                      10.0
# 2024-09-01 00:00:00         130.0                      10.0
# 17                            NaN                       NaN
# 18                            NaN                       NaN
# 19                            NaN                       NaN
# 20                            NaN                       NaN
# 21                            NaN                       NaN
# 22                            NaN                       NaN
# 23                            NaN                       NaN
# 24                            NaN                       NaN
# 25                            NaN                       NaN
# 26                            NaN                       NaN
# 27                            NaN                       NaN
# 28                            NaN                       NaN
# 29                            NaN                       NaN
# 30                            NaN                       NaN
# 31                            NaN                       NaN
# 32                            NaN                       NaN
# 33                            NaN                       NaN
# 16                            NaN                       NaN
# 34                            NaN                       NaN
# 35                            NaN                       NaN
# 36                            NaN                       NaN
# 37                            NaN                       NaN
# 38                            NaN                       NaN
# 39                            NaN                       NaN
# 40                            NaN                       NaN
# 41                            NaN                       NaN
# 42                            NaN                       NaN
# 2023-06-01 00:00:00           NaN                       NaN
# 2023-07-01 00:00:00           NaN                       NaN
# 2023-08-01 00:00:00           NaN                       NaN
# 11                            NaN                       NaN
# 12                            NaN                       NaN
# 13                            NaN                       NaN
# 14                            NaN                       NaN
# 15                            NaN                       NaN
# 10                            NaN                       NaN
#
#                      PIED DE POULE SOFT  TUL GLITTER ESTRELLAS
# 2023-09-01 00:00:00                45.0                   36.0  \
# 2023-10-01 00:00:00                44.0                   40.0
# 2023-11-01 00:00:00                43.0                   43.0
# 2023-12-01 00:00:00                42.0                   45.0
# 2024-01-01 00:00:00                42.0                   47.0
# 2024-02-01 00:00:00                41.0                   48.0
# 2024-03-01 00:00:00                41.0                   49.0
# 2024-04-01 00:00:00                41.0                   49.0
# 2024-05-01 00:00:00                41.0                   49.0
# 2024-06-01 00:00:00                41.0                   50.0
# 2024-07-01 00:00:00                41.0                   50.0
# 2024-08-01 00:00:00                40.0                   50.0
# 2024-09-01 00:00:00                40.0                   50.0
# 17                                  NaN                    NaN
# 18                                  NaN                    NaN
# 19                                  NaN                    NaN
# 20                                  NaN                    NaN
# 21                                  NaN                    NaN
# 22                                  NaN                    NaN
# 23                                  NaN                    NaN
# 24                                  NaN                    NaN
# 25                                  NaN                    NaN
# 26                                  NaN                    NaN
# 27                                  NaN                    NaN
# 28                                  NaN                    NaN
# 29                                  NaN                    NaN
# 30                                  NaN                    NaN
# 31                                  NaN                    NaN
# 32                                  NaN                    NaN
# 33                                  NaN                    NaN
# 16                                  NaN                    NaN
# 34                                  NaN                    NaN
# 35                                  NaN                    NaN
# 36                                  NaN                    NaN
# 37                                  NaN                    NaN
# 38                                  NaN                    NaN
# 39                                  NaN                    NaN
# 40                                  NaN                    NaN
# 41                                  NaN                    NaN
# 42                                  NaN                    NaN
# 2023-06-01 00:00:00                 NaN                    NaN
# 2023-07-01 00:00:00                 NaN                    NaN
# 2023-08-01 00:00:00                 NaN                    NaN
# 11                                  NaN                    NaN
# 12                                  NaN                    NaN
# 13                                  NaN                    NaN
# 14                                  NaN                    NaN
# 15                                  NaN                    NaN
# 10                                  NaN                    NaN
#
#                      TUL GLITTER MOTAS
# 2023-09-01 00:00:00               27.0
# 2023-10-01 00:00:00               26.0
# 2023-11-01 00:00:00               26.0
# 2023-12-01 00:00:00               26.0
# 2024-01-01 00:00:00               26.0
# 2024-02-01 00:00:00               26.0
# 2024-03-01 00:00:00               26.0
# 2024-04-01 00:00:00               26.0
# 2024-05-01 00:00:00               26.0
# 2024-06-01 00:00:00               26.0
# 2024-07-01 00:00:00               26.0
# 2024-08-01 00:00:00               26.0
# 2024-09-01 00:00:00               26.0
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
# 30                                 NaN
# 31                                 NaN
# 32                                 NaN
# 33                                 NaN
# 16                                 NaN
# 34                                 NaN
# 35                                 NaN
# 36                                 NaN
# 37                                 NaN
# 38                                 NaN
# 39                                 NaN
# 40                                 NaN
# 41                                 NaN
# 42                                 NaN
# 2023-06-01 00:00:00                NaN
# 2023-07-01 00:00:00                NaN
# 2023-08-01 00:00:00                NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 10                                 NaN
#
# [49 rows x 369 columns]
#                       descrip  ventas_2024
# 0                     ACETATO     258618.0
# 1                  ALEMANISCO         67.0
# 2          ALEMANISCO PREMIUN        454.0
# 3                   ANTISOLAR      15903.0
# 4    ANTISOLAR BASKET REGULAR        650.0
# ..                        ...          ...
# 364              SARGA VENETA       1799.0
# 365  MUSELINA SPANDEX PLISADA        126.0
# 366        PIED DE POULE SOFT        542.0
# 367     TUL GLITTER ESTRELLAS        606.0
# 368         TUL GLITTER MOTAS        339.0
#
# [369 rows x 2 columns]

# %%
df_resumen
# Out:
#                       descrip  ventas_2024
# 0                     ACETATO     258618.0
# 1                  ALEMANISCO         67.0
# 2          ALEMANISCO PREMIUN        454.0
# 3                   ANTISOLAR      15903.0
# 4    ANTISOLAR BASKET REGULAR        650.0
# ..                        ...          ...
# 364              SARGA VENETA       1799.0
# 365  MUSELINA SPANDEX PLISADA        126.0
# 366        PIED DE POULE SOFT        542.0
# 367     TUL GLITTER ESTRELLAS        606.0
# 368         TUL GLITTER MOTAS        339.0
#
# [369 rows x 2 columns]

# %%
import plotly.express as px

# Crear una tabla resumen con la sumatoria de las predicciones para cada producto
df_resumen = df_predicciones.sum(axis=0).reset_index()
df_resumen.columns = ['descrip', 'ventas_2024']

# Crear la gráfica con Plotly Express
fig = px.bar(df_resumen, x='descrip', y='ventas_2024', title='Resumen de Ventas para 2024')
fig.update_layout(xaxis_title='Descripción del Producto', yaxis_title='Ventas Estimadas para 2024')

# Guardar la gráfica en un archivo HTML
fig.write_html("resumen_ventas_2024.html")

# Guardar el DataFrame en un archivo CSV
df_resumen.to_csv("resumen_ventas_2024.csv", index=False)

# Guardar el DataFrame en un archivo Excel
df_resumen.to_excel("resumen_ventas_2024.xlsx", index=False)

# Mostrar la gráfica
fig.show()

# %%
df_resumen.shape
# Out:
# (369, 2)
